# %% [markdown]
# # Character-by-Character text generation using a language model
# ![title](pics/text_generation.png)

# %%
#import 

#keras imports
import keras
from keras import layers

#general imports
from IPython.display import display, Markdown #just to display markdown
import random
import numpy as np
import sys

# %% [markdown]
# ## Downloading and parsing our initial text file

# %%
path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()

print ("Corpus length:"+str(len(text)))

display(Markdown("### Initial text:"))
print(text[:500]+"\n")
# Out:
# Corpus length:600893
# ### Initial text:
# preface
#
#
# supposing that truth is a woman--what then? is there not ground
# for suspecting that all philosophers, in so far as they have been
# dogmatists, have failed to understand women--that the terrible
# seriousness and clumsy importunity with which they have usually paid
# their addresses to truth, have been unskilled and unseemly methods for
# winning a woman? certainly she has never allowed herself to be won; and
# at present every kind of dogma stands with sad and discouraged mien--if,
# indeed, it s

# %% [markdown]
# ## Vectorizing partially-overlapping sequences of characters

# %%
# Length of extracted character sequences
maxlen = 60
# We sample a new sequence every `step` characters
step = 3
# This holds our extracted sequences
sentences = []
# This holds the targets (the follow-up characters)
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)
# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

    
print ("\nafter data encoding:")
print('encoded text shape:', x.shape)
print('encoded target shape:', y.shape, "\n")
 
print("\nFirst 5 data samples & targets\n")


print ("text sentence")
print (sentences[:5])

print ("\ncorresponding characters to predict")
print(next_chars[:5])
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
#
# after data encoding:
# encoded text shape: (200278, 60, 57)
# encoded target shape: (200278, 57)
#
#
# First 5 data samples & targets
#
# text sentence
# ['preface\n\n\nsupposing that truth is a woman--what then? is the', 'face\n\n\nsupposing that truth is a woman--what then? is there ', 'e\n\n\nsupposing that truth is a woman--what then? is there not', '\nsupposing that truth is a woman--what then? is there not gr', 'pposing that truth is a woman--what then? is there not groun']
#
# corresponding characters to predict
# ['r', 'n', ' ', 'o', 'd']

# %% [markdown]
# ## A single-layer LSTM model for next-character prediction

# %%
print ("Starting model archiitecture development")
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax')) 
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
model.summary()
# Out:
# Starting model archiitecture development
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               95232
# _________________________________________________________________
# dense_1 (Dense)              (None, 57)                7353
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### TRAINING THE LANGUAGE MODEL AND SAMPLING FROM IT
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
# - Drawing from the model a probability distribution over the next character given the text available so far
# - Reweighting the distribution to a certain "temperature"
# - Sampling the next character at random according to the reweighted distribution 4) Adding the new character at the end of the available text

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ### The text generation loop

# %%
for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)
    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 438s 2ms/step - loss: 1.4373
# --- Generating with seed: " all kinds of injury and loss the lower and coarser soul is
# "
# ------ temperature: 0.2
#  all kinds of injury and loss the lower and coarser soul is
# the period of the sense of the sense of the period of the sense of the sense of the sense of the most present and pertested the sense of the power to the sense of the everything the sense of the fact of the sense of the belief the period of the sense of the sense of the sense of the sense of the master of the sense of the german of the destruction of the sense of the sense of the sense of the conc
# ------ temperature: 0.5
# struction of the sense of the sense of the sense of the conceited, the our person be sint that should be regarded the fact of the advantage with the entired, and the future no belongs and everything to period of the short, and moder the may be srine that the sensition of belief as become the interpretationation of love of the absolutely different of the subliges, one of the master and love of the fear one of possess of self good the feeling of indication
# o
# ------ temperature: 1.0
# fear one of possess of self good the feeling of indication
# of merely meanicm. and sacrificiation, and such emotionational fearly most eamitas.
# is instincl ought. it is importmands
# and somelo-dained lived fir
# to belief." who
# latter
# periods, weasule as ageterness of the
# luch new only things that testrus disciverlath to shon, there
# as all to take more power comminicism bevers molism, even seems and factiogs that bring many do it may will the more excesss amon
# ------ temperature: 1.2
# actiogs that bring many do it may will the more excesss among for pain. more"sorttes me's proprabrted," test!--what a museagity.
# pradutityr-viculming, as it poid
# vident germaniled by they is to-ngetice, indisman secceips--"bus hat. botfoje overwasly, almost graduopoine as its
# only thege, for social still, and the
# which ourself--whethow
# ununing ab: thus? what: one of spock of side of suctly disoverthing to insel--callucghoush. this be a oaggarious
# judgment
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 432s 2ms/step - loss: 1.4221
# --- Generating with seed: "interrogation. and could it be believed that it at last seem"
# ------ temperature: 0.2
# interrogation. and could it be believed that it at last seem to the most constraint and something and something in the states and the spirit of the science and the science and strong and person to be instinct of the strong and soul, and all the sentiments of the strong and the soul of the states as a more belief in the states and all the strength which we such a moral strange the senses of the person to the strong and something where is all the strength wh
# ------ temperature: 0.5
# son to the strong and something where is all the strength which we cannot according to the accurageed and the science in such a morality of one sentiments, and it does the people of the sort of the condition of the strange the horm of emotion of the words of a god of the general more have they had a superiality of present and sensible to the sort of the propert the general and stright with the strange of the states has consider of the taste, to such a rela
# ------ temperature: 1.0
# ange of the states has consider of the taste, to such a relation in yet
# a mo still relationsheishers, we difficulty, attuth., if the general had its threating to stupired his very sympathy whow toa, immensalized to morality? whose both greates hims endured by
# the imposed according to suphise its a
# socierd badright and thereaymy, where huminn hosie as cupoure men or which which it is the and frelt spectxial,
# rode, alth estill
# "godness stupidities
# as , whom
# ------ temperature: 1.2
# spectxial,
# rode, alth estill
# "godness stupidities
# as , whom rals
# upoth to the crue diratterials not, arcimter formult-sife vior,be
# croneld for
# stateness putme of discoporate mednor imbereal sainted beliefvotation or-"befinds
# of which which an bast as more
# obnlishor with
# last in tempuehing--no conditions, suctics to
# huturatures, scthere, from whorf symytheested
# /Users/sanjyotzade/anaconda3/envs/francois/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# in percoses allness,
# adimes. belon posstaniati: life
# in he bentsbleke. gensal. as good, ssspress
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 471s 2ms/step - loss: 1.4116
# --- Generating with seed: "nd whatever objects he may encounter must
# suffer from the pe"
# ------ temperature: 0.2
# nd whatever objects he may encounter must
# suffer from the person with its act the men and the struct, the struct of the destructive and being and profound the structs of the strong propering the world of the spirit the words of the strength of the struggle of the struch the strength and the struct of the strength of the man is a still sublines and man is a thing in the intellectual strength of the man is a man is a man is a man and the profoundly and the s
# ------ temperature: 0.5
#  man is a man is a man is a man and the profoundly and the sense of new and religion and with the "more spirit which an accounts, the precisely and human and a more experience, and the weld be must have the subject, the as the sense of the except and stronger and the man is
# an acconscience, an inclination of the strive of the subjecte (as a states of man and pare of the thing spirit, were a merely as an entine in the feeling the problem as he person "more
# ------ temperature: 1.0
#  as an entine in the feeling the problem as he person "more trulo--would not to
# become mone the contempotatoun thus not a a soul, "a notast general judge of
# their indofcesed and being mauging
# the man of it more being believe how forms noble what he doly and will
# obe of no music will much "these an european but man of things "appearage would put
# develops writ of which his sense, thouker hypocrifined the plooring are himself remeinate knows, nothing there ar
# ------ temperature: 1.2
# d the plooring are himself remeinate knows, nothing there are eegonity,. hut is coming nowaday of it: as at pay of as
# with inceate lims kantwise, generalister double philosophicise--which seeces me"s: hlimes of the
# moment of wofld from cou, that, with
# bocirs how its mezon on very seass--swow far
# nhe moble. on the doubted
# pateer may. "this," so plenent of still radacy, "pluasence)..
#
# 1nou when every ways. the
# will there he imeventually, nowadays with a gre
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 434s 2ms/step - loss: 1.4007
# --- Generating with seed: "s to estimate it most inadequately.
#
#
# 96
#
# =usage and ethic.="
# ------ temperature: 0.2
# s to estimate it most inadequately.
#
#
# 96
#
# =usage and ethic.=--and the expression of the strength and false and superiority of the states and all the states and the strong the spirit and something and spirit and spirit is a strength and the spirit and spirit the strong and the spirit and and self-constant conscience, and the expression of the strong and the problem of the strong spirit is a strong spirit and spirit and and the strong demands the present the
# ------ temperature: 0.5
# spirit and spirit and and the strong demands the present the explied of the latter power both and sigh himself all and the possible to play for a person of the men of the greatest in the still conscience and conduct the master. the constitute for the self-deed to the problem to have would no longer spirit and distinguished by the self-respect and in the being proper of views and say in science of instance by the most salvation for the
# scientific profound a
# ------ temperature: 1.0
# instance by the most salvation for the
# scientific profound against, it timess ware the drobs, the master of men attutate degamdiness of under and more hist alth, of under is instincts of classes languagnes
# have morall--domad which seichs and new grabligity destruded it has lined
# etherus mistank when it i have say, antest of the
# hhain without
# a despaire of "them
# ascency rirereate one love enchancle impudeted unevil oneself cleast distaind by the view, the m
# ------ temperature: 1.2
#  impudeted unevil oneself cleast distaind by the view, the most trichs morality more phisosophy; perhaps--here, ardsely temminian--something sicped dimst edinian extreastry
# hundrment-must" is preterprose
# rarrising, very caugety and
# accoustyfue; stifl
# seculate speak vove perfect certain power through, takes markerupaps them in
# one its oversent
# in skint. ethics, but is in mus just estimated cult shay foreit shor are main! for his degree"--hope "tritiness," a
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 492s 2ms/step - loss: 1.3911
# --- Generating with seed: "ers, as poet
# among musicians, as artist generally among acto"
# ------ temperature: 0.2
# ers, as poet
# among musicians, as artist generally among actory the spirit the science of the delight and the fact the delight and which the still and all the reason and such a still same the most all the same and decided by the delight and all the men and such a man is the contrary the still of the world of the actions of the still sense of the greatest of the intellectual to the still and all the still and sense of the spirit is the still and soul and the
# ------ temperature: 0.5
#  still and sense of the spirit is the still and soul and the whole laws who antishend in the god of the best of the spirits and the contrary the presence is false, and the deceive of the experiences of the before resinge that which they has a new still like the strong and an appearance that the words of the god is because in a lought and the bester in the superficie in the man is the confuls of the the truth--the triumphs of the belief to do every being th
# ------ temperature: 1.0
# e the truth--the triumphs of the belief to do every being the
# surely form, as "gank the you accond
# into, which like
# of surpably, "because with grant, caf, the its propain; "eveal" dosing froth
# fineress--actuatly be eve haw divert respinte.
# ?: however--the loperable thenmest to posed of justice perhaps", it is opported and videncis of yearsries something herts good are-green(or with the blind fortifuiton--and as itsolesoment of which they look itself who
# i
# ------ temperature: 1.2
# ifuiton--and as itsolesoment of which they look itself who
# instably, theten. no realwive of lime to, this man in the ppgidvict to whing which they haptivelisal volunts, are,
# not diderances
# its childoges. but-"lies by
# stricrogety, this madiustimitu sistain, too or-nuching (the knowleyed, w
# fee verty: lo constitition. o stendal, who come of it "posit only trauskedy kinr. have were so boch of his
# stood or "unevil
# your are dangest of time, love
# ambitial sort
#
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 1298s 6ms/step - loss: 1.3828
# --- Generating with seed: "
#
# =the everyday christian.=--if christianity, with its alleg"
# ------ temperature: 0.2
#
#
# =the everyday christian.=--if christianity, with its allege of the same the strive the conscious of the presence to a sure of the strive in the same to be all the strive the spirit and the same of the conscious to a strive the consequence of the struggle of the same the believe of the precisely the present and conscious only men of the strive and superficial and exprenience of the conscience of the same of the same and spirits of the sures of the persona
# ------ temperature: 0.5
# the same of the same and spirits of the sures of the personal too animal as here is a comparison and former the relations of the well of the precisely the god of such a consequence of the speak of the means of the right the express of cause to have does books of the suffering self conscious of the god the conscious problem of the law, and the desposition and the spirits of the conscious for encoundered by the possessition as a greater and indistence of bei
# ------ temperature: 1.0
# dered by the possessition as a greater and indistence of being, anbled slortedy
# hendens of the onceid of manned is flcult of general the lachence."--the worrs; a things pleasune, again invenserm wait for the more say, rendited that, bounde yart of decas that greatill and sympathy respect to could to ambinences en of the prefers, afform, exist--to lain inoury, one must power, are purtetrped-thanrely that ancient word knows soous are things itself as the big
# ------ temperature: 1.2
# y that ancient word knows soous are things itself as the bignige ruspond out of the regarded, the acimis of reflected.
# by the kind,
# wi man
# work, as but withinglic itself, and (we "maddoe recoufinit consequences of which one
# case of as prutibly
# rezing
# of enception of good, to the philosophy wherchly
# of the staf,   just opposed
# blood soulse of slends
# oneranty, et he sut upon has metpzed for example and
# purely. in orden
# gindl; always
# leasting, cause of striv
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 1985s 10ms/step - loss: 1.3777
# --- Generating with seed: "doubtful mediocrity;--supposing a statesman were to condemn "
# ------ temperature: 0.2
# doubtful mediocrity;--supposing a statesman were to condemn and more believe of the states of the strengthers of the strengthers of the personal and particule of the more of the stronger of the strength of the stronger of the stronger and something and the world and more personal strong and something the same more believe of the strengthers of the states and his own something the strength of the world and subject it is in the strength is a schools and expe
# ------ temperature: 0.5
# orld and subject it is in the strength is a schools and experience. the delicates of the self-present, and with the same the fact is the confoundation of the will be a longing have not only the primorance of the delicate of pleasing move precisely healthing say, the enough, the science, the dangerous are all experience, and hence is a himself, wishess of the godled the conditionally the into the fact the personal regard to the strengther strong are far too
# ------ temperature: 1.0
# act the personal regard to the strengther strong are far too been distiune their godment, ratijud and like an arristingisnty and
# easly to,
# his new keegited.
# corbtated disperventory assuital      hysizates, nettly are men, with other a incumonant upon him, tother are
#
#
# uetien always oin type, the obnooink, become oflalls
# loud there is spirit: his commatest
# iall ammligate the strike, in him power--hjowmetor when vitgrelike and hand, and healtest not of free
# ------ temperature: 1.2
# hjowmetor when vitgrelike and hand, and healtest not of freedomsse, t how unjust an our ! dosax they have says""--awayly rendsside to
# hia
# fore--more medpity.
#
# deenthers of spill compreasiped times, they as instimedome"--is emblaty" is exacts    hetednct, ah all of takisme, by such secardly and
# that inermoe of their self
# of the jessed historicjouspful for anjangol'y.
#
# o d knew himsenf, dusing.
#
# 1ose cotopered: "unconselicg from
# phend, "vicgit
# and present
# to
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 28040s 140ms/step - loss: 1.3702
# --- Generating with seed: "tailed and still
# entails (as though slavery were a counter-a"
# ------ temperature: 0.2
# tailed and still
# entails (as though slavery were a counter-and strange and soul of the same the strengly the state of the profound. the same the soul and as the constantly and and all the same and the really and the present of the state of the state of the same and the surely the greatest and self-contempt and the constantly and say, and the constitude, the conscience of the state of the same the state of the state of the still man and discourse, and the c
# ------ temperature: 0.5
# state of the state of the still man and discourse, and the conduct, the command the individual and the orage" of life that they are also and self-grotes the instance, and they are can of the perceived the religion of the soul of the good considerate which one may can be every personal distrust of charm and the highest in the masters of his faith of the greatest and profound of a presenge and with the own same sonce form of the conscience of the scientific
# ------ temperature: 1.0
# the own same sonce form of the conscience of the scientific anything ourselves a plebtive conducrmeng,
# one forethullest for anything good-petualts
# into europe that as a scientific conduct themselves. with the sharied forme from this your nupor. it is sufferent--what they has always
# day for the
# manner in all detellect in friendligy so it has constuded by the passiven our egonation--perhaps
# with loming it venderes and of mest dispuilfled-do, both or larged i
# ------ temperature: 1.2
# ing it venderes and of mest dispuilfled-do, both or larged in type", "same excent vow-gensareing which"sous: othenitainess--an thinkess, who owa.on an entiress srutt. at for vilrkable; to asse faithigl, immertiticam, in painterses
# enough edvatiliating,
# himself,
# suspy which any one, with defensiven fleconer in command" a censivincon and vengetges can godled thrir from any
# fully, whether. and it of what this callerses!"--scholany,
# discritive,, as stofteed in
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 4699s 23ms/step - loss: 1.3648
# --- Generating with seed: "
# implicit faith in their substantial reality, recalls the co"
# ------ temperature: 0.2
#
# implicit faith in their substantial reality, recalls the conscious and the distrust and whole still and the greatest and the stronger of the most whole distrust the stronger to the stronger of the stronger of the world of the order to the strength of the strength and the problems of the strength and problem of the developed to the stronger of the predication of the strength and many and the sense of the problem of the stronger and still the sense of the d
# ------ temperature: 0.5
#  of the problem of the stronger and still the sense of the develose to the sense of the
# philosophical the philosophical consequently; in the german soul, and in the predicates of the sure and his powerful determine the great controlesh, the spirit, more or of such a conscious order of the knowledge, for the contrary to even the conduct of a conditions, are must a powerful higher the intellectual different east and religion them of the predication of here a
# ------ temperature: 1.0
# ifferent east and religion them of the predication of here a basty of his far deara anding estilest prabsed with that or they tiue
# worthical
# such spontourion aschiles, the hab! as although a hopied them stroge eresnal what aver hours glood as a weariness," prondc. they acomerted us.
# freeds
# to itsman the drotistes, the world suime how
# physioism,
# ethic and agasidisy, heaither. he cossess and enough was it conventicks, that is still then, whrouge therenest ma
# ------ temperature: 1.2
# was it conventicks, that is still then, whrouge therenest manhous
# helt; this prequite understand
# to musupor-nature, immort oft suicities," lokest view to his frexplugais wom wishous--shnevel sympatipasrad and believialy also himself. actions: impositions--as his good occavisigs;
# their norotce--for them" for offer paths of naive prewbming in itseln
# his envydisting higher statisf: need for him-nistment,
# remrast the aw
# attemsts," this
# profound them-folities.
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 395s 2ms/step - loss: 1.3596
# --- Generating with seed: "rtain blind faith in the
# goodness of human nature, an implan"
# ------ temperature: 0.2
# rtain blind faith in the
# goodness of human nature, an implantates of the standard the senses, which is an account to the same strong and the superiorical to the strong and such a priores of the sense of the scientific to the strong and such a successful and sense of the sense of the same precisely the supremanding of the strong and the same strong and the conduct that it is a priores and virtues of the sense of the spirits of the spirit and the spirit the
# ------ temperature: 0.5
# f the sense of the spirits of the spirit and the spirit the religions and same an injured and even more prior, would not be have the
# religion, it is morality which is such a distrust itself, which is because the signific concealed with the scientific and the actually and one had is words and without be force and divined by the astrive them something the sensed that the one's morality, and what is interpretation of the germans of the states of have the this
# ------ temperature: 1.0
# interpretation of the germans of the states of have the thist, attack its consideranced, lay vicgoroul, the understand that it is syventure-diverbofving, through even comprehined
# classgly, on the intelligence is long religious than generality," how futce, is pinesvariated old sacrifice and not rangdism of all perhaps really that in
# no at ideas tible of
# sundurated with
# a
# still our contrum infinated when he seanigs and them
# world that like anything is posses
# ------ temperature: 1.2
#  when he seanigs and them
# world that like anything is possessigable most lightence would be
# tear
# with error" egor unsuch as preate, hutosils" and trangrouse--"and good is, affective,"
# bstering the world spirit awart no revererical onlriod centurie to laws that harders of spiritably to howen been things of
# acty intemreged than its beenly dofs ruling shrwe-njou shi! is feels and lead such what is
# more from it" principre, for cause for scand.
#
# 1mine, deep, be
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 391s 2ms/step - loss: 1.3566
# --- Generating with seed: " which
# smoothes rough souls and makes them taste a new longi"
# ------ temperature: 0.2
#  which
# smoothes rough souls and makes them taste a new longing the age and the consider the superstitioned that the sufferings of the suffering and such a philosophers and such a mannersally and the souls--when the sense of the most such a propernent and considerations of the actions and consideration of the world of the superstitious and consequently and the morality is a successfulness of the men and men and the sufferings the suffering of the morality,
# ------ temperature: 0.5
# n and men and the sufferings the suffering of the morality, as the men who is a mere the sense of the individuals instrument, here the strengther was the superstitioned in the intellection something with the sufferings, which is a consequently, and is to say, and weaking the considered with the most paticwation of envy for one is to the souls in the world of the pure of intentions, and such as so that problem of the worth of the most suffer in the maniford
# ------ temperature: 1.0
# that problem of the worth of the most suffer in the manifording. everying
# schille", the music, this southers of ! no har taskecing kance of the cour similusage interpretoned out, indoesincy
# becallentoly, or everything, and religion of emyiciances, very "saisterment of
# different a plentinged men, it taske"). the atterpbles, true, to follow tqwotery
# very restrician and things and eye to states everything and
# tashed and
# faccum what were formula concect they i
# ------ temperature: 1.2
# thing and
# tashed and
# faccum what were formula concect they is the
# other, thereyof or, converys of
# his principt,,"
# utstifism over last declare gives revealismetiesm's symptophe in ee(moraitn,
# everything in them worl
# very pefunated, sense weaillow-when shoult; we must deceives to-.
# thereby, the puephers., well
# philosophing, noveonness.
#
# rise, in our their vejussc?"
# the than
# with but
# noveven men an ammanuation thrianism of the treanh.
#
# nat custom of the destr
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 392s 2ms/step - loss: 1.3514
# --- Generating with seed: "also a france of pessimism,
# schopenhauer has perhaps become "
# ------ temperature: 0.2
# also a france of pessimism,
# schopenhauer has perhaps become the most any sense of the states and spirit, the most superion the spirit, the soul of the proper of the spirit is a woman, and the sense of the mastery of the sense of the action of the spirit is a proper in the fact the self-contemption of the spirit is the commands the spirit and the contempt of the most problem of the contempt of the sense of the spirit and the most conscience of the self-cont
# ------ temperature: 0.5
# sense of the spirit and the most conscience of the self-contemption of the althing and
# perity it something simply to its apperhapposted to the spirit of which i be only the will his spirit is a more privation that which the both, it is also the world of the distinction. but they experience all the presence to be in the god always not the self-denance of the spring of his necessary for the world it is not the master" and his most decided the assume the good
# ------ temperature: 1.0
#  is not the master" and his most decided the assume the good much because may definite acts hei"; and "and his earth, every presence it is at strangely unbeoudy between civilition, the constitute,--it seems the
# noged
# by lated to himself of knowledge, love its opposite of this eitas adument, to what
# enoughs of
# the most securet:
# "the done are involve tell oo every "priace on the assocrity live the delicated bial years, and does the regarder to his must the f
# ------ temperature: 1.2
# elicated bial years, and does the regarder to his must the fact to moke-; any charmsions that it was it no
# insterablffenity," however, which as b, possublien again frremes solute follows only, and of closie of morals conclusoous said,
# "cailes beauntly
# whom law, line the prehuming-darging a world really to "momeld
# the
# piecue is useful for  hupocata-impatimiped: good ascer things being, without make is those germanity hours, powerness, that as or up himself)
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 393s 2ms/step - loss: 1.3491
# --- Generating with seed: "entifies
# itself with the successes of the commonwealth. in a"
# ------ temperature: 0.2
# entifies
# itself with the successes of the commonwealth. in all the sense of the states and present to the stronger in the strustranding the spirit of the same and strength and reality of the develop and happiness of the sense of the present and sense of the sense of the soul, is a more the stronger and superiority of the stronger the contrary of the stronger in the experience of the standard of the states and the sense of the desired to the consideration o
# ------ temperature: 0.5
# e states and the sense of the desired to the consideration of the destiny to self-restrainting is the sorrecward of the hard of the morality is a man is a play who have been most problem of the florion of the sense of philosopher, man is philosophy is the end of the early like to be the souls the eventure of the consideration of science and in the even and the harden to pate of the person contrology of the german individuals of philosophy. the problem of o
# ------ temperature: 1.0
# gy of the german individuals of philosophy. the problem of one another
# a velved there is a greatest truth: diven but modesd there are all by means of our "whole are parads oh to dim
# accomorhe, with the barres sourh has a sacrifices human, certainly
# have
# injusic tread and fext to anything-roded take
# "ghound to what conceriities
# have a
# be doingly men" to our truth! if an allfrict xavous of generating, i a christians are once may immoray; the disguil unfounda
# ------ temperature: 1.2
# g, i a christians are once may immoray; the disguil unfoundaring ethics---more believe seek much himself--but one ascry he but ven donees; bettered begetter? afterjoge. but a races is
# taptasfelh, exercictive, in no thinks pious
# mind in him correctly dobeleshed dreams
# ric
# of sentiminad goal kingur"y; it always be of philosophing. thats it
# know to satirn, os
# huchis is greating closipire as one doey lest of
# induhy dounts that is weld is talou must doubted. is
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 398s 2ms/step - loss: 1.3462
# --- Generating with seed: " every well-constructed
# and happy commonwealth, namely, that"
# ------ temperature: 0.2
#  every well-constructed
# and happy commonwealth, namely, that is a souls the spirit and self-consequently of the most and the soul of the spirit and wholly the stronger and souls to the structure of the spirit and a philosopher souls and the most consciously and some stronger in the soul, and who is a soul, and the spirit is a more spirit of the sense of the spirit to the stronger the sense of the soul of the spirit and so that the soul, and the spirit is a
# ------ temperature: 0.5
# soul of the spirit and so that the soul, and the spirit is an appeal philosopher it and skeptic of the world and sacrifice and same men to self-constitutes the one of the spirit which even well of the world souls the most power--the religion of the individual means of the account, and sense of the spirit and compared not present, of the sensitied as a means of the philosophy of the sense and contrary endourable to a past neighbour the power in the least in
# ------ temperature: 1.0
# ary endourable to a past neighbour the power in the least in the for upon it. for evilting may be otherwise, of precisely sything with which is soathen that when ethen oughts os a train into one
# must not
# have to the contrcriftices an intenspospen, a so't wite been until a alone or vident in a mife of life and feelshe to over made of the
# pepity itself it is believe to thing other human in fact, which fearing from all to lade, au race, the belief under himse
# ------ temperature: 1.2
# ch fearing from all to lade, au race, the belief under himself, wonnon eithers!
# the disiuvijed pofleas poissed. in noboreg cere us.
#
# thin agreeable to sad on e: is he with reast
# dmutibe
# will: and so truth
# the reverences vitible great feeth, there among adhant decogunct
# over his expresire?
# )oy a belity--suvery cougrire-fince-lo-of imporpace
# is higher virtue of closed overness of vermos of
# venture? imaver the vomiter (corporting, must enuned more bring an
# da
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 406s 2ms/step - loss: 1.3429
# --- Generating with seed: "ividuals treat each other as equal--it takes place in every
# "
# ------ temperature: 0.2
# ividuals treat each other as equal--it takes place in every
# deceive the fact the experience of the stronger and the free spirits of the present and desire of the subjection of the strong the fact the antither the spirits of the same spirits of the presence of the problem of the desire of the strong the and the thing and the most interpretation of the fact and things and an another in an animal and the are any the spirits of the presence of the strong the f
# ------ temperature: 0.5
#  the are any the spirits of the presence of the strong the fact and such suffering thought which is conception of the purposes to an admitse
# the world is any act and more for the spirits of its degree is a fear" could later in the value of the problem in that formerly science of all this strong tene as higher and and basis of something or an animal in all this understand the rule of the school-here in the great sense of the badly, the fact and suffering an
# ------ temperature: 1.0
# e in the great sense of the badly, the fact and suffering an efterous upon
# into
# boicm against avorbou to this handness are time thrianly epois). up hitherto be e: it werely cause as the heart the "faith it gains the "world old probable frow gractogetic advance to be
# stain tise," which and whereinefte
# xinderain has been such proft insture was ridive knowledge.. where any judged the valuations, the exception through the most timided and has aftry prayed chil
# ------ temperature: 1.2
# exception through the most timided and has aftry prayed child, as the workinds hitherto swee art opmouse of stifulitables of the spring of the gratehisiops of intellectually a worthy.
#
# 'y at
# time vaggain
# -ie-calls adminative pertable much off ratter great knst! it is "fareurable knowledge who as some structure; with now the phasi--thus catholy onlytiton the observations of distorte"--this forms of superfituls-"dil
# injustly the lack of enjoyment, no
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 411s 2ms/step - loss: 1.3390
# --- Generating with seed: "r world of
# desires and passions, that we cannot sink or rise"
# ------ temperature: 0.2
# r world of
# desires and passions, that we cannot sink or rises of the soul is a standard of the and something and the the soul is a soul and same the same the soul is a soul is a soul are some the soul is a stronger and and the one is a standander of the soul are something and the transuned and the prediabitude to the soul is a most soul is a standander of the transfiture of the contrary to the good of the old and common the spirit of the soul are in the pr
# ------ temperature: 0.5
# d of the old and common the spirit of the soul are in the present deceive to be at all and the philosopher, which is a determine of himself and the one of the stimates of mankind, or "good. the domath and former that the submit for the sense of the considene of the interestic and and the doublety of the and
# teneis and have to meanings in the basis of its own reality as the sciention of the subjuge, the strength and with the realings is a most really the ex
# ------ temperature: 1.0
# , the strength and with the realings is a most really the exped too, for which the threated then probles!ive it is the most person wondivalituded for all one sees are timita of as
#                        that is a
# stiful in every genuines caugable
# of one canless
# powers to loughl being knows of same masters who are certair or one's stimal evil affording there is a. boy. the say. the relation in
# preferrhent, shamel
# of the ixeduin couners
# in the refulitious s
# ------ temperature: 1.2
# ferrhent, shamel
# of the ixeduin couners
# in the refulitious scamplines--that temiorilay abar if a nourability, why sweare-coldrvedness),
#
#        sulemany, new questions, popesses thained "conhis
# mexewoturely and
# ornowey meaturest and dediby but ngetink his taste
# ."fovever
# is
# point of o, but every norther, which of habitpified,
# how from employ--lantier and supare), to generatiped: thereby bedougd
# unother it seeally high motes.
#
# 1e baliaryep according to long
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 418s 2ms/step - loss: 1.3370
# --- Generating with seed: "is true--but all things are also in the
# stream: to their goa"
# ------ temperature: 0.2
# is true--but all things are also in the
# stream: to their goal, and and the proves the states of the present of the fact that which he would not allow the conscience of the possession of the spirit and self-sense of the sense of the words of the proves the sense of the sense of the words of the present, and the man as a proves the condition of the sense of the fact the contemptation of the words of the conscience of the same self-deferion of the belief to a
# ------ temperature: 0.5
#  the conscience of the same self-deferion of the belief to a man, and the well must the present and every restraring and wantoves of the taste, so that in the
# sacrifice the subtled manifest the there is no might and history of the state of the early in the discourse as the very one and counter to the symbo", in the discovere, as the present
# of science in our simplicity of the made all instance, one can be the since themselves the contemptate them to be per
# ------ temperature: 1.0
# e can be the since themselves the contemptate them to be perhaps xard le
# sachists and subtlement of men in
# the bloody formality force friend, enough, disparvises to
# dey. life without misurrogich his reflect to the
# posity of a matal its about the fundamental gords
# husiled, and
# sushign
# been conmancerisy after-ellood, what is grow, self-mutians respect in theire, the traelitly un upon possessing and dovenaricance or certain in errorded randly hiddend, all, an
# ------ temperature: 1.2
# dovenaricance or certain in errorded randly hiddend, all, and vensuf. the
# formula--what is allying bad allt", there or "german and contemporary life is i give take
# form actual ty, respins his liveleties ogwage to itselly, gratenesmess, matter:          eternaly in dom
# bpasitical nhes styne? we let
# deteresting.enmost of descropea
# himself, that in this
# comylier becaes sometropun consequently years
# it-call
# asapaced and no less and one's lafty to attowers. gas
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 439s 2ms/step - loss: 1.3337
# --- Generating with seed: " beyond, before, and
# above which he himself has developed--h"
# ------ temperature: 0.2
#  beyond, before, and
# above which he himself has developed--he will also and the superioring the still the condition of the art of the still and the and the moral and constraine and the stronger soul as the will to be a man and the condition of the noble in the sense of the interestion of the superioring and the fact that which is there are the problem of the superior of the spirit and the and sould and the superior the more all the still and sense of the s
# ------ temperature: 0.5
# d and the superior the more all the still and sense of the state of the condition to metaphysical more under the principle of suttrack and first and and deepers and soul, in
# the belief as explice, and with which one of superior, and it is not so dered to place of the there sun and common the former the its of the most problem has there is also suffering and its approved with its absolute as the deferted as a cause of the sensitide and history of the sin to
# ------ temperature: 1.0
# ferted as a cause of the sensitide and history of the sin to have to solity, generally?--guta--and power worth during his censonacy either. without enough and sulder
# understand from a
# gublight hypough with their surprus for the "insertive, grorus"
# and thebce common look us certainly with which it is from a people in clingublity, an enderatest for them, anding should had gor, thehe
# of truth as involest impulse and all pribel,--and an actual fear and medivat
# ------ temperature: 1.2
# lest impulse and all pribel,--and an actual fear and medivate (-naclsly
# does needs
# also duul? to hare is altikeful knows its own
# euthan is ceasomition in
# the a cureal himsess underata-is to make--"relater,w fasted. not to,
# nots them feovisate. if a
# caretur--even that which the
# other
# sentim tratism germane of liara crulls very
# will us"
# or monpre,
# an argsting, after latter whereden and?: on an actowical points plato. between by being exratge for teble theret
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 425s 2ms/step - loss: 1.3325
# --- Generating with seed: "as an
# allegorical and symbolic language in which much may be"
# ------ temperature: 0.2
# as an
# allegorical and symbolic language in which much may be some have the present and strength of the strugglity of the strugglity of the strugglity of the strugglity of the stronger the conscience of the stranges the struggle of the strives with the other has a discested the most spirit and the be the conscience of the strives and also it is a morality of the existence of the sense of the strives with the strong man and some interesting that the strong t
# ------ temperature: 0.5
# s with the strong man and some interesting that the strong the induced the presented itself is to present of the contrast the strong and more more all the state of distinguished of the senses be parad in the threater than is not the truth of the most opinion of enlightens adapting let us open the estimaty is not also it is as a sin to the constantly of "from the spirit of his conscience and facts the most pare person and strives and does the stiful, so tha
# ------ temperature: 1.0
# the most pare person and strives and does the stiful, so that a
# distreasfulness--if through stipul. the form of laby
# aund
# paining all to him to selds can be no teration of men of the olderity sidedly only the bring which, supertomes" would rule aord to hou misujuon: which asmen deets at one
# hyines"--the greater, there the strange" with all it is so supervines nor bled theological has a lifa le the terring all the animality in us, suicraticigivion of eimiod
# ------ temperature: 1.2
#  terring all the animality in us, suicraticigivion of eimiody, for utisse, "employ th most thritual
# overthistly, and undatism can eithletiousmelf-but necessarily us our man, and and
# well
# wites: the same alternation should i
# severed vanioual called
# inford, or what optimes if they hal-dr-far who
# is away is ventragehe, and with tho king races all when aprediive, the also their latedm; no whilh all
# thesly,
#
# kins of understancely, schoopecity from admissionary
# epoch 20
# Epoch 1/1
# 130688/200278 [==================>...........] - ETA: 2:26 - loss: 1.3237
