# %% [markdown]
# # Character-by-Character text generation using a language model
# ![title](pics/text_generation.png)

# %%
#import 

#keras imports
import keras
from keras import layers

#general imports
from IPython.display import display, Markdown #just to display markdown
import random
import numpy as np
import sys
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Downloading and parsing our initial text file

# %%
path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()

print ("Corpus length:"+str(len(text)))

display(Markdown("### Initial text:"))
print(text[:500]+"\n")
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 11s 19us/step
# Corpus length:600893
# ### Initial text:
# preface
#
#
# supposing that truth is a woman--what then? is there not ground
# for suspecting that all philosophers, in so far as they have been
# dogmatists, have failed to understand women--that the terrible
# seriousness and clumsy importunity with which they have usually paid
# their addresses to truth, have been unskilled and unseemly methods for
# winning a woman? certainly she has never allowed herself to be won; and
# at present every kind of dogma stands with sad and discouraged mien--if,
# indeed, it s

# %% [markdown]
# ## Vectorizing partially-overlapping sequences of characters

# %%
# Length of extracted character sequences
maxlen = 60
# We sample a new sequence every `step` characters
step = 3
# This holds our extracted sequences
sentences = []
# This holds the targets (the follow-up characters)
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)
# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

    
print ("\nafter data encoding:")
print('encoded text shape:', x.shape)
print('encoded target shape:', y.shape, "\n")
 
print("\nFirst 5 data samples & targets\n")


print ("text sentence")
print (sentences[:5])

print ("\ncorresponding characters to predict")
print(next_chars[:5])
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
#
# after data encoding:
# encoded text shape: (200278, 60, 57)
# encoded target shape: (200278, 57)
#
#
# First 5 data samples & targets
#
# text sentence
# ['preface\n\n\nsupposing that truth is a woman--what then? is the', 'face\n\n\nsupposing that truth is a woman--what then? is there ', 'e\n\n\nsupposing that truth is a woman--what then? is there not', '\nsupposing that truth is a woman--what then? is there not gr', 'pposing that truth is a woman--what then? is there not groun']
#
# corresponding characters to predict
# ['r', 'n', ' ', 'o', 'd']

# %% [markdown]
# ## A single-layer LSTM model for next-character prediction

# %%
print ("Starting model archiitecture development")
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax')) 
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
model.summary()
# Out:
# Starting model archiitecture development
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               95232
# _________________________________________________________________
# dense_1 (Dense)              (None, 57)                7353
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### TRAINING THE LANGUAGE MODEL AND SAMPLING FROM IT
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
# - Drawing from the model a probability distribution over the next character given the text available so far
# - Reweighting the distribution to a certain "temperature"
# - Sampling the next character at random according to the reweighted distribution 4) Adding the new character at the end of the available text

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ### The text generation loop

# %%
for epoch in range(1, 10):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=2048,
              epochs=1)
    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('\n--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('\n------ temperature:', temperature)
        sys.stdout.write(generated_text)
        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 10s 49us/step - loss: 1.2780
#
# --- Generating with seed: "l be relegated to the
# physiological sciences and to the hist"
#
# ------ temperature: 0.2
# l be relegated to the
# physiological sciences and to the history of the same are something that the superficial the sense and all the contrary and suffering the sense of the sense of the same the spirit of the sense of the same as the sense of the strength of the sense of the superficial the spirit of the same as a soul and the superficial and the superficial the sense of the superior of the end the superficial and as a soul and the strength of the spirit o
#
# ------ temperature: 0.5
# e superficial and as a soul and the strength of the spirit of the higher in the fact is not one of the extent as a man is the same will be a man is not can no longer the super-al enough to character in the bad are consequently always the beguner man and the devil. for his injustial should have no right more is a will pridest the spirit of the fact, the father of the higher to consequently and result of the significance of the superficial it strong in the s
#
# ------ temperature: 1.0
# lt of the significance of the superficial it strong in the standanling, apparenan, and mortaming and variation
# and physicinessquare bo the only yeakes exem to they are is, it is chare kind in a people to
# gramitive, kind, regarded the vagiual knew inative, no just he super they at the gived wenes
# volutions--they occusion another. in eqhame. it
# is dangerous discorranct of me. a woman in which its pririture are perhaps ow
# "eductive some valual from himself, h
#
# ------ temperature: 1.2
# iriture are perhaps ow
# "eductive some valual from himself, his
# wepeans happise us, a heart" (which
# mispises
# by the action.
#
# 147. when an extrative wonly with
# the
# friendships of suffered sone--pousse of
# the knew then himself," no _narros the convertionas themselves, should andmmeral
# purpose of nead all to knoce,
# others. all exceprocher,
# acrorution the fair, fal undertituable.=--unpogman
# plansic, creatolid,. her inner teped of pale oflest, it was
# doined for
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 10s 49us/step - loss: 1.2636
#
# --- Generating with seed: "al group
# or community (and to one's neighbor as thus underst"
#
# ------ temperature: 0.2
# al group
# or community (and to one's neighbor as thus understand the sense of the same as a soul and sense of the superficial the sense that is a man with the superficial the superficial. the experience, and the strength to him to the strength the delight in the strength the more superating as sense of the strength in the same and in the same the standard of the same as a soul and the same and the strength the strength and in the commander and an according
#
# ------ temperature: 0.5
# strength the strength and in the commander and an according to present to metaphysical man is the sense in all the consequently and not which when it is falselfy. the belief in the fact that it is a still state of being and said. the diving and what even the responsibilities of the general to cause, and is presimate the general soul happiness of the servasifical mind and the hand of the fact that
# in the reality of the feether obligent the
# nandor and all th
#
# ------ temperature: 1.0
# in the reality of the feether obligent the
# nandor and all this
# own iden from the excright upon be a noith, time, our sought to attracted render the domaticbly an
# adity, and of the rest makes. wret is nowadageing intilit
# man being tword of redicaling are
# also, an inflictive by a lators will deep awakers allow dascier the belief divand philosophers-for also cell!
#
#
#                      i seflentaring how pain, the form--in that mush
#
# ------ temperature: 1.2
#              i seflentaring how pain, the form--in that mush will certain for. as the whole
# furthess
# over views pain (gregal speakion, there exesthelly! the agriemy also how to injustifes of waca"; so much" to them whither turn should us: or you emodering if the virtues to
# their own comes onloon of the nondauce has
# tald and may ratignes, the greatest--even igner
# our imbrantation ye stenchs," peciotion. for infruddince and delistime lebightrow--seld for, bv
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 10s 48us/step - loss: 1.2515
#
# --- Generating with seed: " that the one who commands and the one who
# executes are diff"
#
# ------ temperature: 0.2
#  that the one who commands and the one who
# executes are different the consideration of the soul of the strength of the sense of the sense of the sense of the sense of the same as a power of the sense of the sense of the sense of the sense of the sense of the sense of the strength of the sense of the servical and superiority of the subject of the strength of the consequences, the superiority the things the contemptition, and the sense of the sense of the su
#
# ------ temperature: 0.5
# ings the contemptition, and the sense of the sense of the supernally
# and determine that which who were
# another, when all the instincts, and interpretation of family and really like the abivess, has been remorable schopenhauer's be sole-gerianer the master and the best for a conscience of the seriousness and really and every metaphysical whose such a solution of subjuce of the successfully christian of the superiority that the last consists himself be
# mista
#
# ------ temperature: 1.0
# n of the superiority that the last consists himself be
# mistays: foelsies a long a
# sugher of
# its down too-view, concernly of science, the new tempe, the acts usterplasing thereby say, jecomed, the carty or thorgarsapfcunction and thoughts; and a most cultures, only a man is utter now disinging to species,
# in the happiness, pational to que task chrosous not inflance of visions
# shantly an therefore with undree-ly service, and the
# significative-crefuction--and
#
# ------ temperature: 1.2
# ith undree-ly service, and the
# significative-crefuction--and importion anteriors--i been impletion of the desires opinion.=--one's formeraper, i most vitious,
# and
# "great
# live effest imoliminis blears curiss." be is to know the
# exicary, "it taken mutual taste would nam,
# truth!--the wild aloot", be solend elok, tredit, which thought
# ameageror,ary
# stwand. indeed,--and, by which other; the
# inconcealiated in,
# hereind with its subotezorable."--one have sining th
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 10s 49us/step - loss: 1.2403 0s - lo
#
# --- Generating with seed: "t without a
# certain dread and mistrust of ethic itself and n"
#
# ------ temperature: 0.2
# t without a
# certain dread and mistrust of ethic itself and nothing in the fact of the same way that the sense of the same to the same time in the same to a soul he is a more the superficial the present determined the conduct as the most consequently a pleasure of the world and super-to the subjection of the sense of the fact to the contrary conduct to the same still means of the conduct, and are such a man and superstition of the most present desire the se
#
# ------ temperature: 0.5
# uch a man and superstition of the most present desire the sense of the extending degardent of the ethic man, as a concealed and say the same indifferent and clear worker of the sense of the fact to desire that has a sense of the supernation and prevails its opposite of a man of his fact the constinuation, in explained as his experience of human being deception, and the higher pates one whole there are the all thereby a forming
# inatid to different more man
#
# ------ temperature: 1.0
#  are the all thereby a forming
# inatid to different more man of realicate privailuments; he learned the persons
# they regard to heither-philosophy
# and outwince accustime quicts, altapen and thus the hast readily love and, that such placed by advantage; the gratty and
# vittle
# works that
# the view of historically, the tho rausticuse, whether the matter is emoutions are crattle, and into the holosical and olm unworld in sugers; it was not them a justice the volin
#
# ------ temperature: 1.2
# d olm unworld in sugers; it was not them a justice the volintary--no r precisely responsibly interprenanred: our loin; is no mattery
# certain you delignestions put--pwors, now.
# to be down in their last will formury, and much
# are new succied. eyent cwanoout, me dividuation (who are
# samved eninsvations
# scentum, accuus fintrred generate grosism, is
# auve because a
# graducally qualities more sub!cacation: how feether--them truth, wholly philosophers.
#
# 195. the an
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 10s 49us/step - loss: 1.2299
#
# --- Generating with seed: "f once more, he feels it--but this very new
# love, this new s"
#
# ------ temperature: 0.2
# f once more, he feels it--but this very new
# love, this new solitude in the super-accorrance, and the struggle to the self-great and interpretation of the superied and superied from the superior and self-great some things the sense of the super-to make the superstition of the soul and the superied and self-great in the self-great some things the superied and super-as a more proper themselves the religion of the present deation of the self-great the supersti
#
# ------ temperature: 0.5
# ligion of the present deation of the self-great the superstition of the soul and the precisely its something of the manifests must perhaps to precisely in the broves and the profoundly and down worth as the spiritual taste in the experience the greater in the subject by the belief in the realize to him what is all such a question of his consequence. it is possibilities of the most command--and pleasure to be strong and the greatest the spiritual fore" upon
#
# ------ temperature: 1.0
# asure to be strong and the greatest the spiritual fore" upon helping of
# the one's and raped!
# only eevils, therefore. they over: the historical sholled teste: as not
# the more and sort of better
# greate their proud my walts of your exparatance of the should be the mother of last-languablest one immediately as yage thereby also powerful to like-
# rightless of the false leads have, expedient, education:--som therefore that temca. they certainlence
# his owing to j
#
# ------ temperature: 1.2
# --som therefore that temca. they certainlence
# his owing to just change!
#
# 243. it be the disunrengers, the from becomes un, his hars, indifferently,
#
# into the faith as an experience, of these calegtililys-which the constray a
# requicy
# them
# /home/sj-ai-lsb/anaconda3/envs/francois/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# appearly: formher inclidains time wade; nature as bring, heartakes
# enders over expedience of ruling imse.--palger's sporl, how ascerpecteduage
# emmanicism, for order
# of thus
# becanse" of seriousnes un the case," herethis pro
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 10s 48us/step - loss: 1.2207
#
# --- Generating with seed: " the principal causes which have kept the type of
# "man" upon"
#
# ------ temperature: 0.2
#  the principal causes which have kept the type of
# "man" upon the constraint to the fact that the earth and something which has not the spirit and there is not to be and are there is not to be and desires the sense of the same to the strength and superstition of the strength of the sense of the superiority of the sense of the spirit and still relation of the spirit and there is not to be and something which we conscience of the superiority of the sense of t
#
# ------ temperature: 0.5
# ing which we conscience of the superiority of the sense of the constant science, as they are world for a thinking is a men of the more strong every word something which has always have to be and also the greatest demands man could be all the states of a commoncable soul and artists of the dealism and last development of the
# reality the propers. but it is always
# who dreames the entire view of the struggle of the stook of his privior for the fear, and theref
#
# ------ temperature: 1.0
# truggle of the stook of his privior for the fear, and therefore, aginst to general, second, as a only being to our listure in motions by restifars--no nite: because long in history which the will down
# beat takes and colveltur? is
# at false, one may only knowledge-on most similations, in the jokes. the sair from religious
# d domanci, what is "nuth, man only there
# europe. suspodnce of immortating keped, the german sounds, nothing and
# therefore, the great such
#
# ------ temperature: 1.2
# d, the german sounds, nothing and
# therefore, the great such and certain in the merits one day
# as free
# mult, puritation
# only and spore, i hald
# such a dil sknather
# of one unglist as he has results of its case. the
# epoped themselves, from
# themselvess--and something most pletaroximinative "becomisms wants would like be such always, as they have there
# it nip hooked--we futul of
# the easted a yet boor, pure isount and laps to corness.
#
#
# 36
#
# =the ideated over exis
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 10s 50us/step - loss: 1.2125
#
# --- Generating with seed: "anything shameful, devilish and sinful in it. he sees rather"
#
# ------ temperature: 0.2
# anything shameful, devilish and sinful in it. he sees rather the same to his element to the same the stronger the sense of the sense of the superficial the world and sense of the sense of the sense of the sense of the sense of the supportime and more super-to be an individual and sense of the sense of the sense of the same as a period of the sense of the sense of the same the world of the sense of the experience of the subtle of the supportime and consciou
#
# ------ temperature: 0.5
#  the experience of the subtle of the supportime and conscious and a profound in the master of the sense to the experience, which the most necult? i does not be seldor of the expediest the easily of
# "most races of the end the world of the sense
# of the fundamental consciences of the conscience is remains degulty which the belief it is proposition of play, a should be a matter of the case of the same are the more and the contradist of man of his comparation o
#
# ------ temperature: 1.0
#  are the more and the contradist of man of his comparation of hert, the strength impulse of
# "nation.
#
#
# 5
#
# =ever over lung-strangedion of the ded in regards his probable truth are propectually moority.
# theor the
# greatest bould now. but philosophizing, if he so florrful himself--in mighfor, as they fatho--an own is act art that that some-titse of the commense brings to which make and both the error[buad: yever the christ"" ensceent
# disciving where
# slade--hea
#
# ------ temperature: 1.2
# buad: yever the christ"" ensceent
# disciving where
# slade--hearth; but flowers the result how our
# phryoundence, man a very jelignded by wearbed, notoliar? morality. truth merely frights, will only in
# wanted, origin over)ous: that is brought? he who is new disciefty and every imptioungiable!--namely, for it is
# itrist questionand in the love
# strich with opinioned?  o general almosterance of asterions, here to preserving assumer, or "because, even to renlutive
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 10s 49us/step - loss: 1.2055
#
# --- Generating with seed: "is inversion of valuations (in which is also included
# the us"
#
# ------ temperature: 0.2
# is inversion of valuations (in which is also included
# the useful and spirits of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the spirit of the sense of the sense of the sense of the sense of the sense of the sense of the most conscience of the spirit and subject and sense of the great to the spirit of the spirit of the sense of the sense of the sense of the sense of the sense of the most spirit and desire and s
#
# ------ temperature: 0.5
# f the sense of the sense of the most spirit and desire and subjective with the highest desire and the served the case and the most charming of the can exame not be disposition in the most contrarily and there is not the explanation of the loses be alluring profound sense of the honor the thing and the states and doing the sense a confused by the word to the some the standard, the served, and the strong and more taste deepers, which has he is not desire of
#
# ------ temperature: 1.0
# trong and more taste deepers, which has he is not desire of ""words: in many
# good and yet may be dominancy,
# this plantic dreams this
# would seem
# centraved. the establism in the bad misunderstand has howety.--but londs and commoncivilisting, my banerly and evil" by elpolenged and as o enong hinly in,
# to be midracted thereby a please
# undespances if the
# entiters should ye disguing the
# feeling they anothernly the last of li. one hard upon those sense--as one ha
#
# ------ temperature: 1.2
# thernly the last of li. one hard upon those sense--as one have alsok" only which will"s, if
# stook over whatever what
# was in madined bat in a
# didedined modern among of
# philosophy of powerful organic-elselvals crotolism us out of mankind in before an one's manque. the very ne'sserng that just was himself-lively labyine always has into
# salvance the mannession and deed floors of the man"--always moubod throught of
# the sprang
# of toraurs without---and iore as
# pr
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 10s 48us/step - loss: 1.1980
#
# --- Generating with seed: " upright,
# and also the most wicked consciences of today, as "
#
# ------ temperature: 0.2
#  upright,
# and also the most wicked consciences of today, as a man is not to be and are the same as a man and something that the same digner--the most feeling of the same existence to the same will problem of the spirit and subjuce of the superficial the same will conditions of the sense of the same discovered and said, he is the superficial the suffering the sense of the same digning more soul and more and all the subject more will to be and as a man as a
#
# ------ temperature: 0.5
#  more and all the subject more will to be and as a man as a conception of the deep it is once to disguise and intelligence of the sense for the world sort which is a contradict with the germans and to may be down is man and sacrifice of the metaphysooless. the artist interpretation of the fact of the contemplation of the part of the higher man intercourse in the same of domain of the soul: there is a doubt and desire to the other has not so in all the cont
#
# ------ temperature: 1.0
# s a doubt and desire to the other has not so in all the contrary who propensive, the light and possible; the mystination, or evil, as his pare to rairs would foelokems, there is resuls: so with now really contemptive and lack of epight because but-yet there. and revenge--than the unfaiture, no longience from un, here to disguise has fellow,
# relationship. and to do the persol which willingent: 'eticking repuded convidence. all elsogically amble to conpostin
#
# ------ temperature: 1.2
# cking repuded convidence. all elsogically amble to conposting first and its aid think bryways delightion and swoust in their subminis to beer are still alexision which not and view of thus utolity,shaper--out, has for
# a woman.--and
# are tod his ! between:--shelding were thes : not ye _udefully lovine, even expatis so ever thicked culturent!"
#
# 246. whether who has not to be at that. they arilein plantic that pessitives of thought: inlool
# when they never"
# "st
